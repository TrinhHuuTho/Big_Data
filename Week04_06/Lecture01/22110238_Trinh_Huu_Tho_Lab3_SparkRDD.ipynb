# %% [markdown]
# # Lab 3 - Spark RDD Lab
#
# - Họ và tên: Trinh Huu Tho
#
# - MSSV: 22110238

# %% [markdown]
# ## Khởi tạo SparkContext

# %%
import findspark
findspark.init()

import pyspark
findspark.find()

from pyspark import SparkContext
sc = SparkContext()

# %% [markdown]
# ## 1. Tạo một RDD từ một collection
# ### 1.1 Tạo một Python list gồm các số từ 1 đến 100

# %%
numb = range(1, 100)

# %% [markdown]
# ### 1.2. Tạo một RDD từ Python list

# %%
numbRDD = sc.parallelize(numb)

# %% [markdown]
# ### 1.3. In ra kiểu của `numbRDD`

# %%
print("The type of RDD is", type(numbRDD))
# Out:
# The type of RDD is <class 'pyspark.core.rdd.PipelinedRDD'>

# %% [markdown]
# ## 2. Tạo một RDD từ một external dataset
# ### 2.1. Tạo một RDD từ một file

# %%
file_path = "C:/spark/README.md"  # File readme của thư mục cài đặt Spark
fileRDD = sc.textFile(file_path)

# %% [markdown]
# ### 2.2. Kiểm tra kiểu của `fileRDD`

# %%
print("The file type of fileRDD is", type(fileRDD))
# Out:
# The file type of fileRDD is <class 'pyspark.core.rdd.RDD'>

# %% [markdown]
# ## 3. Phân hoạch dữ liệu
# ### 3.1. Kiểm tra số partition của `fileRDD`

# %%
print("Number of partitions in fileRDD is", fileRDD.getNumPartitions())
# Out:
# Number of partitions in fileRDD is 2

# %% [markdown]
# ### 3.2. Tạo `fileRDD_part` từ `file_path` với 5 partitions

# %%
fileRDD_part = sc.textFile(file_path, minPartitions = 5)

# %% [markdown]
# ### 3.3. Kiểm tra số partition của `fileRDD_part`

# %%
print("Number of partitions in fileRDD_part is", fileRDD_part.getNumPartitions())
# Out:
# Number of partitions in fileRDD_part is 5

# %% [markdown]
# ## 4. Map and Collect
# ### 4.1. Tạo một map() transformation để tính lũy thừa bậc 3 của các phần tử trong `numbRDD`

# %%
cubedRDD = numbRDD.map(lambda x: x**3)

# %% [markdown]
# ### 4.2. Collect kết quả

# %%
numbers_all = cubedRDD.collect()

# %% [markdown]
# ### 4.3. In ra các phần tử từ `numbers_all`

# %%
for numb in numbers_all:
	print(numb)
# Out:
# 1
# 8
# 27
# 64
# 125
# 216
# 343
# 512
# 729
# 1000
# 1331
# 1728
# 2197
# 2744
# 3375
# 4096
# 4913
# 5832
# 6859
# 8000
# 9261
# 10648
# 12167
# 13824
# 15625
# 17576
# 19683
# 21952
# 24389
# 27000
# 29791
# 32768
# 35937
# 39304
# 42875
# 46656
# 50653
# 54872
# 59319
# 64000
# 68921
# 74088
# 79507
# 85184
# 91125
# 97336
# 103823
# 110592
# 117649
# 125000
# 132651
# 140608
# 148877
# 157464
# 166375
# 175616
# 185193
# 195112
# 205379
# 216000
# 226981
# 238328
# 250047
# 262144
# 274625
# 287496
# 300763
# 314432
# 328509
# 343000
# 357911
# 373248
# 389017
# 405224
# 421875
# 438976
# 456533
# 474552
# 493039
# 512000
# 531441
# 551368
# 571787
# 592704
# 614125
# 636056
# 658503
# 681472
# 704969
# 729000
# 753571
# 778688
# 804357
# 830584
# 857375
# 884736
# 912673
# 941192
# 970299

# %% [markdown]
# ## 5. Filter and Count
# ### 5.1 Áp dụng filter trên `fileRDD` để chọn ra những dòng có từ `Spark`

# %%
fileRDD_filter = fileRDD.filter(lambda line: 'Spark' in line)

# %% [markdown]
# ### 5.2. Cho biết có bao nhiêu dòng từ `fileRDD`?

# %%
print("The total number of lines with the keyword Spark is", fileRDD_filter.count())
# Out:
# The total number of lines with the keyword Spark is 20

# %% [markdown]
# ### 5.3. In 5 dòng đầu của `fileRDD`

# %%
for line in fileRDD_filter.collect()[:5]: 
  print(line)
# Out:
# # Apache Spark
# Spark is a unified analytics engine for large-scale data processing. It provides
# rich set of higher-level tools including Spark SQL for SQL and DataFrames,
# pandas API on Spark for pandas workloads, MLlib for machine learning, GraphX for graph processing,
# [![PySpark Coverage](https://codecov.io/gh/apache/spark/branch/master/graph/badge.svg)](https://codecov.io/gh/apache/spark)

# %% [markdown]
# ## 6. ReduceBykey and Collect
# ### 6.1. Tạo một `PairRDD` tên `Rdd` như sau:

# %%
Rdd = sc.parallelize([(1,2),(3,4),(3,6),(4,5)])

# %% [markdown]
# ### 6.2. Áp dụng `reduceByKey()` operation trên Rdd

# %%
Rdd_Reduced = Rdd.reduceByKey(lambda x, y: x + y)

# %% [markdown]
# ### 6.3. Duyệt và in ra kết quả

# %%
for num in Rdd_Reduced.collect(): 
    print("Key {} has {} Counts".format(num[0], num[1]))
# Out:
# Key 1 has 2 Counts
# Key 3 has 10 Counts
# Key 4 has 5 Counts

# %% [markdown]
# ## 7. SortByKey and Collect
# ### 7.1. Sắp xếp `Rdd_Reduced` theo khóa giảm dần

# %%
Rdd_Reduced_Sort = Rdd_Reduced.sortBy(lambda x: x[1], ascending=False)

# %% [markdown]
# ### 7.2. Duyệt và in ra kết quả

# %%
for num in Rdd_Reduced_Sort.collect():
    print("Key {} has {} Counts".format(num[0], num[1]))
# Out:
# Key 3 has 10 Counts
# Key 4 has 5 Counts
# Key 1 has 2 Counts

# %% [markdown]
# ## 8. CountingBykeys
# ### 8.1. Đếm số key khác nhau

# %%
total = Rdd.countByKey()

# %% [markdown]
# ### 8.2 Kiểm tra kiểu của biến `total`?

# %%
print("The type of total is", type(total))
# Out:
# The type of total is <class 'int'>

# %% [markdown]
# ### 8.2. Duyệt và in ra kết quả

# %%
for k, v in total.items(): 
  print("key", k, "has", v, "counts")
# Out:
# key 1 has 1 counts
# key 3 has 2 counts
# key 4 has 1 counts

# %% [markdown]
# ## 9. Tạo biến `baseRDD` từ file và thực hiện các transform
# ### 9.1 Tạo biến `baseRDD` từ `file_path`

# %%
file_path = 'C:/spark/README.md'
baseRDD = sc.textFile(file_path)

# %% [markdown]
# ### 9.2. Biến đổi các dòng trong `baseRDD` thành các từ

# %%
splitRDD = baseRDD.map(lambda x: x.split())

# %% [markdown]
# ### 9.3. Đếm tổng số từ

# %%
print("Total number of words in splitRDD:", splitRDD.flatMap(lambda x: x).count())
# Out:
# Total number of words in splitRDD: 524

# %% [markdown]
# ## 10. Loại bỏ stop word và áp dụng reduce opperator trên tập dữ liệu
# ### 10.1. Chuyển các từ sang dạng chữ thường (lower case) và loại bỏ các stop words từ biến `stop_words`

# %%
stop_words = ['a', 'an', 'the', 'is', 'be', 'was', 'were', 'it', 'this', 'that', 'but', 'if', 'or', 'not']
splitRDD_no_stop = splitRDD.flatMap(lambda x: x).filter(lambda word: word.lower() not in stop_words)

# %% [markdown]
# ### 10.2. Tạo các tuple có dạng (word, 1)

# %%
splitRDD_no_stop_words = splitRDD_no_stop.map(lambda w: (w, 1))

# %% [markdown]
# ### 10.3. Đếm tần số của mỗi từ

# %%
resultRDD = splitRDD_no_stop_words.reduceByKey(lambda x, y: x + y)

# %% [markdown]
# ## 11. In tần số của mỗi từ
# ### 11.1. Hiển thị 10 từ đầu và tần số của nó trong `resultRDD`

# %%
for word in resultRDD.take(10):
	print(word)
# Out:
# ('#', 1)
# ('analytics', 1)
# ('for', 13)
# ('Scala,', 1)
# ('Python,', 2)
# ('and', 9)
# ('R', 1)
# ('(Deprecated),', 1)
# ('optimized', 1)
# ('supports', 2)

# %% [markdown]
# ### 11.2 Hoán đổi giữa key và value trong `resultRDD`

# %%
resultRDD_swap = resultRDD.map(lambda x: (x[1], x[0]))

# %% [markdown]
# ### 11.3. Sắp xếp các key theo thứ tự giảm dần

# %%
resultRDD_swap_sort = resultRDD_swap.sortByKey(ascending=False)

# %% [markdown]
# ### 11.4. Hiển thị 10 từ xuất hiện nhiều nhất trong `resultRDD_swap_sort`

# %%
for word in resultRDD_swap_sort.take(10):
	print("{},{}". format(word[1], word[0]))
# Out:
# to,16
# Spark,15
# for,13
# and,9
# ##,9
# ```,8
# on,8
# run,7
# can,6
# ```bash,6
